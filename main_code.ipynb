# %% [markdown]
# <a href="https://colab.research.google.com/github/phebetan/dsp-gamescribe/blob/main/main_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import pipeline

# Load and preprocess data
# steam_games_df = pd.read_csv("path_to_steam_games_dataset.csv")
# steam_reviews_df = pd.read_csv("path_to_steam_reviews_dataset.csv")

# Merge datasets if needed

# Preprocess data
# Clean descriptions, handle missing values, etc.

# Split data into train and test sets
train_df, test_df = train_test_split(steam_games_df, test_size=0.2, random_state=42)

# Initialize NLP pipeline
nlp = pipeline("text-classification", model="distilbert-base-uncased", tokenizer="distilbert-base-uncased")

# Train NLP model
nlp_train_data = [{"text": row["description"], "label": row["success_metric"]} for _, row in train_df.iterrows()]
nlp(nlp_train_data)

# Evaluate NLP model
nlp_test_data = [{"text": row["description"]} for _, row in test_df.iterrows()]
predictions = nlp(nlp_test_data)

# Evaluate predictions and calculate metrics

# Fine-tune model if necessary

# Use sentiment analysis for popularity score
# Calculate popularity score from reviews

# Train language model with descriptions and popularity score
language_model_train_data = [{"text": row["description"], "popularity_score": row["popularity_score"]} for _, row in steam_games_df.iterrows()]
# Train language model with the data

# Save or deploy models for future use
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e941b15d15fe> in <cell line: 3>()
#       1 import pandas as pd
#       2 from sklearn.model_selection import train_test_split
# ----> 3 from transformers import pipeline
#       4
#       5 # Load and preprocess data
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1378             value = self._get_module(name)
#    1379         elif name in self._class_to_module.keys():
# -> 1380             module = self._get_module(self._class_to_module[name])
#    1381             value = getattr(module, name)
#    1382         else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
# ...
